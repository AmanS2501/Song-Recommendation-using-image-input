# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/archive_dataset.zip" -d "/content/dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1449).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (145).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1450).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1451).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1452).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1453).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1454).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1455).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1456).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1457).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1458).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1459).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (146).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1460).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1461).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1462).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1463).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1464).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1465).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1466).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1467).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1468).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1469).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (147).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1470).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1471).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1472).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1473).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1474).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1475).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1476).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1477).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1478).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1479).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (148).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1480).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1481).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1482).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1483).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1484).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1485).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1486).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1487).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1488).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1489).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (149).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1490).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1491).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1492).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1493).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1494).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1495).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1496).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1497).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1498).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1499).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (15).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (150).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1500).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1501).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1502).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1503).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1504).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1505).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1506).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1507).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1508).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1509).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (151).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1510).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1511).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1512).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1513).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1514).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1515).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1516).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1517).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1518).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1519).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (152).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1520).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1521).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1522).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1523).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1524).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1525).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1526).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1527).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1528).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1529).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (153).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1530).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1531).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1532).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1533).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1534).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1535).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1536).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1537).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1538).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1539).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (154).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1540).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1541).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1542).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1543).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1544).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1545).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1546).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1547).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1548).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1549).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (155).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1550).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1551).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1552).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1553).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1554).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1555).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1556).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1557).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1558).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1559).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (156).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1560).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1561).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1562).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1563).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1564).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1565).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1566).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1567).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1568).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1569).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (157).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1570).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1571).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1572).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1573).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1574).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1575).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1576).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1577).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1578).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1579).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (158).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1580).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1581).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1582).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1583).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1584).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1585).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1586).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1587).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1588).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1589).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (159).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1590).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1591).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1592).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1593).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1594).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1595).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1596).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1597).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1598).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1599).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (16).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (160).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1600).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1601).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1602).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1603).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1604).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1605).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1606).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1607).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1608).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1609).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (161).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1610).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1611).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1612).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1613).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1614).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1615).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1616).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1617).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1618).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1619).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (162).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1620).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1621).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1622).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1623).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1624).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1625).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1626).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1627).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1628).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1629).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (163).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1630).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1631).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1632).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1633).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1634).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1635).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1636).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1637).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1638).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1639).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (164).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1640).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1641).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1642).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1643).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1644).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1645).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1646).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1647).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1648).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1649).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (165).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1650).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1651).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1652).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1653).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1654).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1655).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1656).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1657).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1658).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1659).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (166).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1660).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1661).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1662).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1663).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1664).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1665).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1666).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1667).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1668).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1669).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (167).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1670).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1671).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1672).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1673).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1674).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1675).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1676).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1677).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1678).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1679).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (168).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1680).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1681).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1682).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1683).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1684).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1685).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1686).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1687).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1688).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1689).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (169).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1690).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1691).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1692).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1693).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1694).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1695).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1696).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1697).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1698).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1699).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (17).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (170).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1700).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1701).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1702).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1703).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1704).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1705).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1706).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1707).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1708).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1709).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (171).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1710).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1711).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1712).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1713).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1714).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1715).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1716).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1717).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1718).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1719).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (172).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1720).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1721).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1722).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1723).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1724).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1725).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1726).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1727).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1728).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1729).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (173).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1730).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1731).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1732).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1733).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1734).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1735).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1736).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1737).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1738).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1739).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (174).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1740).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1741).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1742).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1743).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1744).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1745).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1746).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1747).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1748).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1749).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (175).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1750).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1751).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1752).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1753).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1754).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1755).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1756).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1757).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1758).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1759).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (176).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1760).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1761).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1762).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1763).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1764).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1765).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1766).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1767).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1768).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1769).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (177).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1770).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1771).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1772).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1773).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1774).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1775).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1776).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1777).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1778).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1779).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (178).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Training Data/Glacier/Glacier-Train (1780).jpeg
# ...
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (261).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (262).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (263).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (264).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (265).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (266).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (267).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (268).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (269).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (27).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (270).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (271).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (272).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (273).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (274).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (275).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (276).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (277).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (278).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (279).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (28).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (280).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (281).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (282).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (283).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (284).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (285).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (286).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (287).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (288).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (289).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (29).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (290).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (291).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (292).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (293).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (294).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (295).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (296).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (297).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (298).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (299).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (3).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (30).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (300).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (31).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (32).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (33).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (34).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (35).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (36).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (37).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (38).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (39).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (4).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (40).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (41).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (42).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (43).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (44).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (45).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (46).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (47).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (48).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (49).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (5).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (50).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (51).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (52).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (53).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (54).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (55).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (56).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (57).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (58).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (59).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (6).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (60).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (61).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (62).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (63).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (64).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (65).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (66).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (67).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (68).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (69).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (7).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (70).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (71).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (72).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (73).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (74).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (75).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (76).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (77).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (78).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (79).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (8).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (80).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (81).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (82).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (83).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (84).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (85).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (86).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (87).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (88).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (89).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (9).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (90).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (91).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (92).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (93).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (94).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (95).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (96).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (97).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (98).jpeg
#   inflating: /content/dataset/Landscape Classification/Landscape Classification/Validation Data/Mountain/Mountain-Valid (99).jpeg

# %%
import os
os.listdir('/content/dataset/Landscape Classification/Landscape Classification/Training Data')
# Out:
# ['Glacier', 'Mountain', 'Forest', 'Coast', 'Desert']

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models
from torch.utils.data import DataLoader, random_split
import os

# %%
import torchvision.transforms as transforms

# Define transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize image to 224x224
    transforms.ToTensor(),  # Convert image to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization
])

# %%
dataset_path = "/content/dataset/Landscape Classification/Landscape Classification/Training Data"

dataset_val_path = "/content/dataset/Landscape Classification/Landscape Classification/Validation Data"

dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

dataset_val = datasets.ImageFolder(root=dataset_val_path, transform=transform)

# Check class names
print(dataset.classes)
print(dataset_val.classes)
# Out:
# ['Coast', 'Desert', 'Forest', 'Glacier', 'Mountain']
# ['Coast', 'Desert', 'Forest', 'Glacier', 'Mountain']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Define paths
train_dir = '/content/dataset/Landscape Classification/Landscape Classification/Training Data'
validation_dir = '/content/dataset/Landscape Classification/Landscape Classification/Validation Data'

model = InceptionV3(weights='imagenet', include_top=False)

x = model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)

# Define the model
model = Model(inputs=model.input, outputs=predictions)
# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(
       rescale=1./255,
       shear_range=0.2,
       zoom_range=0.2,
       horizontal_flip=True,
       rotation_range=20,  # Add rotation
       width_shift_range=0.2,  # Add width shift
       height_shift_range=0.2  # Add height shift
)

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(299, 299),
    batch_size=64,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(299, 299),
    batch_size=64,
    class_mode='binary'
)
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
# Unfreeze some layers of InceptionV3 for fine-tuning
for layer in model.layers[:249]:
    layer.trainable = False
for layer in model.layers[249:]:
    layer.trainable = True

# Recompile the model with a lower learning rate
model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples, # train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples, # validation_generator.batch_size,
    epochs=20,    # ... (your other parameters)
    callbacks=[reduce_lr],
)


# Save the model
model.save('/content/drive/MyDrive/model_inceptionv3.h5')
# Out:
# Found 10000 images belonging to 5 classes.
# Found 1500 images belonging to 5 classes.
# Epoch 1/20
#   157/10000 ━━━━━━━━━━━━━━━━━━━━ 3:54:32 1s/step - accuracy: 0.1915 - loss: -5.4496
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 290s 25ms/step - accuracy: 0.1982 - loss: -10.6807 - val_accuracy: 0.2000 - val_loss: -16.2531 - learning_rate: 1.0000e-05
# Epoch 2/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 253s 20ms/step - accuracy: 0.2023 - loss: -16.7825 - val_accuracy: 0.2427 - val_loss: -17.1042 - learning_rate: 1.0000e-05
# Epoch 3/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 206s 20ms/step - accuracy: 0.2435 - loss: -17.2169 - val_accuracy: 0.3013 - val_loss: -17.7586 - learning_rate: 1.0000e-05
# Epoch 4/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 261s 20ms/step - accuracy: 0.2855 - loss: -17.7035 - val_accuracy: 0.3180 - val_loss: -17.8929 - learning_rate: 1.0000e-05
# Epoch 5/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 205s 20ms/step - accuracy: 0.3069 - loss: -17.8743 - val_accuracy: 0.3253 - val_loss: -17.9377 - learning_rate: 1.0000e-05
# Epoch 6/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 205s 20ms/step - accuracy: 0.3149 - loss: -18.0645 - val_accuracy: 0.3340 - val_loss: -17.9613 - learning_rate: 1.0000e-05
# Epoch 7/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 262s 20ms/step - accuracy: 0.3245 - loss: -18.0946 - val_accuracy: 0.3353 - val_loss: -17.9952 - learning_rate: 1.0000e-05
# Epoch 8/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 262s 20ms/step - accuracy: 0.3296 - loss: -18.2014 - val_accuracy: 0.3340 - val_loss: -18.0176 - learning_rate: 1.0000e-05
# Epoch 9/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 262s 20ms/step - accuracy: 0.3345 - loss: -18.2811 - val_accuracy: 0.3327 - val_loss: -17.9119 - learning_rate: 1.0000e-05
# Epoch 10/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 205s 20ms/step - accuracy: 0.3367 - loss: -18.3255 - val_accuracy: 0.3400 - val_loss: -17.9548 - learning_rate: 1.0000e-05
# Epoch 11/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 262s 20ms/step - accuracy: 0.3427 - loss: -18.3835 - val_accuracy: 0.3300 - val_loss: -18.0587 - learning_rate: 1.0000e-05
# Epoch 12/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 205s 20ms/step - accuracy: 0.3456 - loss: -18.4456 - val_accuracy: 0.3413 - val_loss: -17.9931 - learning_rate: 1.0000e-05
# Epoch 13/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 204s 20ms/step - accuracy: 0.3507 - loss: -18.4629 - val_accuracy: 0.3413 - val_loss: -18.0144 - learning_rate: 1.0000e-05
# Epoch 14/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 205s 20ms/step - accuracy: 0.3508 - loss: -18.4818 - val_accuracy: 0.3347 - val_loss: -18.0547 - learning_rate: 1.0000e-05
# Epoch 15/20
# 10000/10000 ━━━━━━━━━━━━━━━━━━━━ 260s 20ms/step - accuracy: 0.3552 - loss: -18.5013 - val_accuracy: 0.3393 - val_loss: -18.1107 - learning_rate: 1.0000e-05
# Epoch 16/20
#    87/10000 ━━━━━━━━━━━━━━━━━━━━ 3:31:21 1s/step - accuracy: 0.3489 - loss: -18.7245

# %%
torch.save(model.state_dict(), "/content/drive/MyDrive/resnet50_model.pth")

# %%
model.load_state_dict(torch.load("/content/drive/MyDrive/resnet50_model.pth"))
model.eval()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load an image from local storage
image_path = "/content/drive/MyDrive/aman.jpg"  # Replace with your test image path
image = Image.open(image_path)

# Apply the same transformations used during training
image_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Convert the image
input_tensor = image_transform(image).unsqueeze(0)  # Add batch dimension

# Move to GPU if available
input_tensor = input_tensor.to(device)

# Predict the class
model.eval()
with torch.no_grad():
    output = model(input_tensor)
    predicted_class = torch.argmax(output).item()

# Get class labels
class_labels = dataset.classes
predicted_label = class_labels[predicted_class]

# Show result
plt.imshow(image)
plt.title(f"Predicted Label: {predicted_label}")
plt.axis("off")
plt.show()

print(predicted_label);

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import numpy as np
import pandas as pd

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from scipy.spatial.distance import cdist

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/drive/MyDrive/data.csv")
genre_data = pd.read_csv('/content/drive/MyDrive/data_by_genres.csv')
year_data = pd.read_csv('/content/drive/MyDrive/data_by_year.csv')

# %%
print(data.info())

# %%
print(genre_data.info())

# %%
print(year_data.info())

# %%
from yellowbrick.target import FeatureCorrelation

feature_names = ['acousticness', 'danceability', 'energy', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence','duration_ms','explicit','key','mode','year']

X, y = data[feature_names], data['popularity']

# Create a list of the feature names
features = np.array(feature_names)

# Instantiate the visualizer
visualizer = FeatureCorrelation(labels=features)

plt.rcParams['figure.figsize']=(20,20)
visualizer.fit(X, y)     # Fit the data to the visualizer
visualizer.show()

# %%
def get_decade(year):
    period_start = int(year/10) * 10
    decade = '{}s'.format(period_start)
    return decade

data['decade'] = data['year'].apply(get_decade)

sns.set(rc={'figure.figsize':(11 ,6)})
sns.countplot(data['decade'])

# %%
sound_features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'valence']
fig = px.line(year_data, x='year', y=sound_features)
fig.show()

# %%
top10_genres = genre_data.nlargest(10, 'popularity')

fig = px.bar(top10_genres, x='genres', y=['valence', 'energy', 'danceability', 'acousticness'], barmode='group')
fig.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

cluster_pipeline = Pipeline([('scaler', StandardScaler()), ('kmeans', KMeans(n_clusters=10))])
X = genre_data.select_dtypes(np.number)
cluster_pipeline.fit(X)
genre_data['cluster'] = cluster_pipeline.predict(X)

# %%
# Visualizing the Clusters with t-SNE

from sklearn.manifold import TSNE

tsne_pipeline = Pipeline([('scaler', StandardScaler()), ('tsne', TSNE(n_components=2, verbose=1))])
genre_embedding = tsne_pipeline.fit_transform(X)
projection = pd.DataFrame(columns=['x', 'y'], data=genre_embedding)
projection['genres'] = genre_data['genres']
projection['cluster'] = genre_data['cluster']

fig = px.scatter(
    projection, x='x', y='y', color='cluster', hover_data=['x', 'y', 'genres'])
fig.show()

# %%
song_cluster_pipeline = Pipeline([('scaler', StandardScaler()),
                                  ('kmeans', KMeans(n_clusters=20,
                                   verbose=False))
                                 ], verbose=False)

X = data.select_dtypes(np.number)
number_cols = list(X.columns)
song_cluster_pipeline.fit(X)
song_cluster_labels = song_cluster_pipeline.predict(X)
data['cluster_label'] = song_cluster_labels

# %%
# Visualizing the Clusters with PCA

from sklearn.decomposition import PCA

pca_pipeline = Pipeline([('scaler', StandardScaler()), ('PCA', PCA(n_components=2))])
song_embedding = pca_pipeline.fit_transform(X)
projection = pd.DataFrame(columns=['x', 'y'], data=song_embedding)
projection['title'] = data['name']
projection['cluster'] = data['cluster_label']

fig = px.scatter(
    projection, x='x', y='y', color='cluster', hover_data=['x', 'y', 'title'])
fig.show()

# %%
# !pip install spotipy

# %%
# !pip install spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from collections import defaultdict
import os


# Replace 'YOUR_CLIENT_ID' and 'YOUR_CLIENT_SECRET' with your actual Spotify API credentials

client_id = '8cd4598f52a34584b7577957a57b99af'
client_secret = '86614e0eccbf4d2bb6d51a472fb202d4'
# Check if the environment variables are set
if not client_id or not client_secret:
    raise ValueError("Spotify API credentials not found in environment variables. Please set SPOTIPY_CLIENT_ID and SPOTIPY_CLIENT_SECRET.")

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

def find_song(name, year):
    song_data = defaultdict()
    results = sp.search(q= 'track: {} year: {}'.format(name,year), limit=1)
    if results['tracks']['items'] == []:
        return None

    results = results['tracks']['items'][0]
    track_id = results['id']

    # Handle potential errors when fetching audio features
    try:
        audio_features = sp.audio_features(track_id)[0]
    except spotipy.exceptions.SpotifyException as e:
        print(f"Error fetching audio features for track {track_id}: {e}")
        return None

    song_data['name'] = [name]
    song_data['year'] = [year]
    song_data['explicit'] = [int(results['explicit'])]
    song_data['duration_ms'] = [results['duration_ms']]
    song_data['popularity'] = [results['popularity']]

    for key, value in audio_features.items():
        song_data[key] = value

    return pd.DataFrame(song_data)

# %%
from collections import defaultdict
from sklearn.metrics import euclidean_distances
from scipy.spatial.distance import cdist
import difflib

number_cols = ['valence', 'year', 'acousticness', 'danceability', 'duration_ms', 'energy', 'explicit',
 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity', 'speechiness', 'tempo']


def get_song_data(song, spotify_data):

    try:
        song_data = spotify_data[(spotify_data['name'] == song['name'])
                                & (spotify_data['year'] == song['year'])].iloc[0]
        return song_data

    except IndexError:
        return find_song(song['name'], song['year'])


def get_mean_vector(song_list, spotify_data):

    song_vectors = []

    for song in song_list:
        song_data = get_song_data(song, spotify_data)
        if song_data is None:
            print('Warning: {} does not exist in Spotify or in database'.format(song['name']))
            continue
        song_vector = song_data[number_cols].values
        song_vectors.append(song_vector)

    song_matrix = np.array(list(song_vectors))
    return np.mean(song_matrix, axis=0)


def flatten_dict_list(dict_list):

    flattened_dict = defaultdict()
    for key in dict_list[0].keys():
        flattened_dict[key] = []

    for dictionary in dict_list:
        for key, value in dictionary.items():
            flattened_dict[key].append(value)

    return flattened_dict


def recommend_songs( song_list, spotify_data, n_songs=10):

    metadata_cols = ['name', 'year', 'artists']
    song_dict = flatten_dict_list(song_list)

    song_center = get_mean_vector(song_list, spotify_data)
    scaler = song_cluster_pipeline.steps[0][1]
    scaled_data = scaler.transform(spotify_data[number_cols])
    scaled_song_center = scaler.transform(song_center.reshape(1, -1))
    distances = cdist(scaled_song_center, scaled_data, 'cosine')
    index = list(np.argsort(distances)[:, :n_songs][0])

    rec_songs = spotify_data.iloc[index]
    rec_songs = rec_songs[~rec_songs['name'].isin(song_dict['name'])]
    return rec_songs[metadata_cols].to_dict(orient='records')

# %%
recommend_songs([{'name': 'Come As You Are', 'year':1991},
                {'name': 'Smells Like Teen Spirit', 'year': 1991},
                {'name': 'Lithium', 'year': 1992},
                {'name': 'All Apologies', 'year': 1993},
                {'name': 'Stay Away', 'year': 1993}],  data)

# %%
# Assume 'data' is your DataFrame containing song information

# Create a dictionary to store keyword associations with song titles
keyword_associations = {
    "Forest": ["If I Were King Of The Forest - Extended Version", "Into The Forest Of Wild Beasts"],  # Add relevant songs
    "Glacier": ["Glaciers of Ice (feat. Ghostface Killah & Masta Killa)", "Past Ice and Ice and Even More"],  # Add relevant songs
    "Desert": ["Desert Places", "Night On The Desert"],  # Add relevant songs
    "Coast": ["Pacific Coast Highway", "West Coast"]  # Add relevant songs
}

def recommend_songs_by_keyword(keyword, spotify_data, n_songs=10):
    if keyword in keyword_associations:
        associated_songs = keyword_associations[keyword]
        song_list = []
        for song_name in associated_songs:
            # Check if the song exists in the data DataFrame
            if any(data['name'] == song_name):
                year = data[data['name'] == song_name]['year'].values[0]
                song_list.append({'name': song_name, 'year': year})
            else:
                print(f"Warning: Song '{song_name}' not found in data DataFrame.")
        # Proceed with recommendations if song_list is not empty
        if song_list:
            return recommend_songs(song_list, spotify_data, n_songs)
        else:
            return "No associated songs found in data DataFrame."
    else:
        return "Keyword not found in associations."

# Example usage
recommendations = recommend_songs_by_keyword(predicted_label, data)
print(recommendations)
